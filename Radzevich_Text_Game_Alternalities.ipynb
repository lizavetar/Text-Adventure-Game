# %%
"""My game is about the time travelling. You will have a chance to go to the future
or to the past. Some of your time jumps will end up with a nice ending and some - not.
There is one little surprise hidden in the Ultimate Question if you familiar with 
The Hitchhiker's Guide to the Galaxy. Name of the game came from my initial inspiration - 
Love, Death and Robots Series, ALternate Histories Episode. Check it out on Netflix!

Bags:
1. Some inputs are not debags for cases like "not to the future", "I choose option 1"
2. time.sleep() not working in couple of places”
3. exit function without sys.exit (not really a bag)"""


def introduction():
    print("""


 █████╗ ██╗  ████████╗███████╗██████╗ ███╗   ██╗ █████╗ ██╗     ██╗████████╗██╗   ██╗
██╔══██╗██║  ╚══██╔══╝██╔════╝██╔══██╗████╗  ██║██╔══██╗██║     ██║╚══██╔══╝╚██╗ ██╔╝
███████║██║     ██║   █████╗  ██████╔╝██╔██╗ ██║███████║██║     ██║   ██║    ╚████╔╝ 
██╔══██║██║     ██║   ██╔══╝  ██╔══██╗██║╚██╗██║██╔══██║██║     ██║   ██║     ╚██╔╝  
██║  ██║███████╗██║   ███████╗██║  ██║██║ ╚████║██║  ██║███████╗██║   ██║      ██║   
╚═╝  ╚═╝╚══════╝╚═╝   ╚══════╝╚═╝  ╚═╝╚═╝  ╚═══╝╚═╝  ╚═╝╚══════╝╚═╝   ╚═╝      ╚═╝   
    """)
    
    starting_path()
    
#-----------------------------------------------------------------------------
def starting_path():
    
    import sys
    import random 
    import time
    global random
    global time
    global host_name
    global name
    
    host_name = 'Alt'
    print("""
------------------------------------------------------------------------------
Hello and Welcome to our brand new, recently open, 73% safe time travel lab!

Here we are offering you an unforgettable experience of jumping back and 
forward in time with unexpectable health issues. And we are happy to have you 
as our first timonaft! 
------------------------------------------------------------------------------
""")

    name = input("Can I ask you for your name? \n\n\t --Your answer: ")
    name = name.capitalize()
    
    print(f"""
------------------------------------------------------------------------------    
Nice to meet you, {name}!
My name is {host_name} and I’m going to be your personal assistant today.
So are you ready to go back to the future?
------------------------------------------------------------------------------
""")

    input("<Press enter to start your adventure.>\n")
    
    start_the_game()
    
#-----------------------------------------------------------------------------
def start_the_game():

    future_or_past = input(f"""
------------------------------------------------------------------------------
Good. Let's go! 
We are offering both future and past time jumps, so where do you want to go? 

Chose one of the options:
1. Future
2. Past
------------------------------------------------------------------------------
\n\t ---{name}'s answer: """)

    future_or_past = future_or_past.casefold()
    
    if future_or_past == '1' or 'future' in future_or_past:
        print(f"""
------------------------------------------------------------------------------
Oh {name}, that’s a brave choice! 
Only best of the best are not afraid to face the future! 
------------------------------------------------------------------------------
        """)
        
        future() #move player to the future
        
    elif future_or_past == '2' or 'past' in future_or_past:
        print(f"""
------------------------------------------------------------------------------
Oh past, sweet past! Make me feel so nostalgic…
Still remember this times when me and my guys was running on Python 1…
------------------------------------------------------------------------------
        """)
        
        past() #move player to the past
        
    else:
        print("Seems like something is wrong.")
    
        you_lost() #moves player to the you lost

#-----------------------------------------------------------------------------          
 #FUTURE 

def future(): 
    
    age = input(f"""
Remind me, how old are you?" \n\t --{name}'s answer: """)
    
    print(f"""
------------------------------------------------------------------------------
Oh {age}! So young, so young...
------------------------------------------------------------------------------
        """)
    
    time.sleep(2)
    
    print(f"""
------------------------------------------------------------------------------
Anyways...
Future is pretty dangerous place so we will ask you sign some papers before.
------------------------------------------------------------------------------
    """)
    
    input("""
<Press enter to give Alternalities full control over your 
money, body, and soul in case something go wrong.>\n""")
    
    print("""
------------------------------------------------------------------------------
Okay good! Let’s hope this aliens are not gonna enslave our tourists again...
------------------------------------------------------------------------------
    """)
    
    input("<Press enter to jump to the future.>\n")
    
    jump_gen = random.randint(1,6)
      
    if jump_gen == 1:
        print("""
------------------------------------------------------------------------------
Oh you are still here! 
Hmm… Seems like you didn’t jump high enough to get to the future. 
Well, sometimes there are just unlucky days, right?
Let's go back to the beginning and start again   
------------------------------------------------------------------------------
        """)
        
        input("<Press enter to go to the beginning of the game.>\n")
            
        start_the_game() #Back to the beginning of the game

        
    else:
        print("""
------------------------------------------------------------------------------
Oh no! That’s exactly what I was afraid of! 
It happened to one of your testers as well. 
So you was enslaves by a superb beings (a.k.a. aliens). Good news is that 
they believe that anyone who is capable of mind-reading should be free. 
They even have it in constitution…
        
Anyhow, the only thing you need to do to be free and get back to your time 
is to simple guess what number your master is thinking about!
------------------------------------------------------------------------------
            """)
    
        ultimate_answer = input(f"""
<Enter answer to the Ultimate Question.>\n\t ---{name}'s answer: """)
        
        if ultimate_answer == '42':
            print("""
------------------------------------------------------------------------------
Correct! Your master is impressed my your mind-reading abilities and set you 
free!You won this game and can retern to you time just after a nice little 
dinner at the End of the Universe Restaurant.

██╗   ██╗ ██████╗ ██╗   ██╗    ██╗    ██╗ ██████╗ ███╗   ██╗██╗
╚██╗ ██╔╝██╔═══██╗██║   ██║    ██║    ██║██╔═══██╗████╗  ██║██║
 ╚████╔╝ ██║   ██║██║   ██║    ██║ █╗ ██║██║   ██║██╔██╗ ██║██║
  ╚██╔╝  ██║   ██║██║   ██║    ██║███╗██║██║   ██║██║╚██╗██║╚═╝
   ██║   ╚██████╔╝╚██████╔╝    ╚███╔███╔╝╚██████╔╝██║ ╚████║██╗
   ╚═╝    ╚═════╝  ╚═════╝      ╚══╝╚══╝  ╚═════╝ ╚═╝  ╚═══╝╚═╝ 
------------------------------------------------------------------------------
                    """)
            
            time.sleep(2)
            you_lost() #Back to restart menu
            
        else:
            print("""
------------------------------------------------------------------------------
            WRONG!!!
Wait! Can’t you read minds? Oh that’s to bad! 
I will try to ask you Master to be kind to you and give you at least a hint.
------------------------------------------------------------------------------
            """)
    
            time.sleep(2)
    
            colors_list = ['red','white','green','blue','yellow','black','pink']

            colors = 0
            colors_chosen = []
            
            while colors < 3:
                colors += 1
                color_chosen = random.choice(colors_list)
                colors_chosen.append(color_chosen)
                colors_list.remove(color_chosen)
                
            print("""
------------------------------------------------------------------------------
Well, he agreed to give you a second chance, but this time you need to guess 
what is master's favorite color.
------------------------------------------------------------------------------
                    """)
            
            color_input = input(f"""
To make it easier for your weak mind master even provide you with 3 options 
to choose from!
Pick one of them: 
1. {colors_chosen[0]}
2. {colors_chosen[1]}
3. {colors_chosen[2]}
            
            --{name}'s answer: """)
            
            print(f"""
------------------------------------------------------------------------------
Good guess! Anyways your master just said to me that he loves all the 
existing colors,so whatever you choise would be a correct answer.

██╗   ██╗ ██████╗ ██╗   ██╗    ██╗    ██╗ ██████╗ ███╗   ██╗██╗
╚██╗ ██╔╝██╔═══██╗██║   ██║    ██║    ██║██╔═══██╗████╗  ██║██║
 ╚████╔╝ ██║   ██║██║   ██║    ██║ █╗ ██║██║   ██║██╔██╗ ██║██║
  ╚██╔╝  ██║   ██║██║   ██║    ██║███╗██║██║   ██║██║╚██╗██║╚═╝
   ██║   ╚██████╔╝╚██████╔╝    ╚███╔███╔╝╚██████╔╝██║ ╚████║██╗
   ╚═╝    ╚═════╝  ╚═════╝      ╚══╝╚══╝  ╚═════╝ ╚═╝  ╚═══╝╚═╝
------------------------------------------------------------------------------
                """)
            
            time.sleep(2)
            you_lost() #Back to restart menu
            
#-----------------------------------------------------------------------------
    
#PAST 
  
def past(): 
    
    time.sleep(3)
    
    print("""
------------------------------------------------------------------------------
Sorry… That were a good days back there. 
So when do you wanna go?
We got 2 tours available now!
------------------------------------------------------------------------------
        """)
    
    past_choice = input(f"""
------------------------------------------------------------------------------
Choose one of your available options:
    1. I want to see dinosaurs! - popular for family vacation!
    2. Handshake with Pharaoh - for young and ambitious!
------------------------------------------------------------------------------
\n\t---{name}'s answer: """)
    
    past_choice = past_choice.casefold()
    
    if past_choice == '1' or 'see dinosaurs' in past_choice:
        print("""
------------------------------------------------------------------------------
And welcome to the 243 million years back!
------------------------------------------------------------------------------
            """)
        
        dino() #moves player to the dino
      
    elif past_choice == '2' or 'handshake with pharaoh' in past_choice:          
        print(f"""
------------------------------------------------------------------------------
Nice choice {name}! If you are wondering when we are now - 1279 BC - 
coronation of Ramses the Great!
Well, he will become the great in some time from now so tssss - it's a secret...
------------------------------------------------------------------------------
                """)  
        
        input("""<Press enter to come closer.>\n""")
        
        pharaoh() #moves player to the pharaoh
    
    else:
        print("Seems like something is wrong.")
        time.sleep(2)
        you_lost() #Back to restart menu
#-----------------------------------------------------------------------------
#DINO

def dino():
    
        time.sleep(2)
        
        dino_choice = input(f"""
------------------------------------------------------------------------------
Look! What a beautiful Stegosaurus chilling right there! 
        
Do you think we can come closer? 
    1. Yup, why not?
    2. Nope, seems too dangerous!
------------------------------------------------------------------------------
\n\t---{name}'s answer: """)
        
        dino_choice = dino_choice.casefold()
        
        if dino_choice == '1' or 'yup'in dino_choice:
            print("""
------------------------------------------------------------------------------
Too bad, this one wasn’t particulate friendly so you got attacked and killed 
by the beautiful Stegosaurus! 
But at least we are gonna take good care about your money 
you lawfully gave to us!

██╗   ██╗ ██████╗ ██╗   ██╗    ██╗      ██████╗ ███████╗████████╗██╗
╚██╗ ██╔╝██╔═══██╗██║   ██║    ██║     ██╔═══██╗██╔════╝╚══██╔══╝██║
 ╚████╔╝ ██║   ██║██║   ██║    ██║     ██║   ██║███████╗   ██║   ██║
  ╚██╔╝  ██║   ██║██║   ██║    ██║     ██║   ██║╚════██║   ██║   ╚═╝
   ██║   ╚██████╔╝╚██████╔╝    ███████╗╚██████╔╝███████║   ██║   ██╗
   ╚═╝    ╚═════╝  ╚═════╝     ╚══════╝ ╚═════╝ ╚══════╝   ╚═╝   ╚═╝ 
------------------------------------------------------------------------------
        """)
            
            time.sleep(2)
            you_lost() #Back to restart menu
            
        elif dino_choice == '2' or 'nope' in dino_choice:
            print("""
------------------------------------------------------------------------------
Wise choice, but you got eaten by the T-rex anyways, so why to bother. 
But at least we are gonna take good care about your money 
you lawfully gave to us!

██╗   ██╗ ██████╗ ██╗   ██╗    ██╗      ██████╗ ███████╗████████╗██╗
╚██╗ ██╔╝██╔═══██╗██║   ██║    ██║     ██╔═══██╗██╔════╝╚══██╔══╝██║
 ╚████╔╝ ██║   ██║██║   ██║    ██║     ██║   ██║███████╗   ██║   ██║
  ╚██╔╝  ██║   ██║██║   ██║    ██║     ██║   ██║╚════██║   ██║   ╚═╝
   ██║   ╚██████╔╝╚██████╔╝    ███████╗╚██████╔╝███████║   ██║   ██╗
   ╚═╝    ╚═════╝  ╚═════╝     ╚══════╝ ╚═════╝ ╚══════╝   ╚═╝   ╚═╝ 
------------------------------------------------------------------------------
        """)
            
            time.sleep(2)
            you_lost() #Back to restart menu
            
        else:
            print("Seems like something is wrong")
            time.sleep(2)
            you_lost() #Back to restart menu
#-----------------------------------------------------------------------------
    
def pharaoh():        
        
    print("""
------------------------------------------------------------------------------
One of the guards notice you, but your fancy clothes and latest iPhone 
convince him to ask his boss before killing you. Lucky for you head of the 
guards decides that you a blessing sent to please a Pharaoh on his coronation 
day. He takes you to the Pharaoh, highest monarch go the modern Egypt.  

Btw, in acient Eygupt people care a lot about maners and proper etiquette 
so you better beheave nicely!
------------------------------------------------------------------------------
            """)
    
    while True:
        pharaoh_choice = input(f"""
------------------------------------------------------------------------------
You enter a big room with filled with highest of the highest nobles of Egypt. 
All eyes are on you.
What will you do?
    1. Kneel and kiss Pharaoh's feet.
    2. Congratulate, wish long reign and shake Pharaoh's hand.
    3. Ask if there will be a party after.

P.S. Please enter only 1,2 or 3.
------------------------------------------------------------------------------            
\n\t---{name}'s answer: """)
        
        if pharaoh_choice == '1':
            break
            
        else:
            if pharaoh_choice == '2':
                break 
                
            else:
                if pharaoh_choice == '3':
                    break
                    
                else:
                    print("""\n\nSorry, I didn't get what do you mean.
I will repeat the last question for you, but this time choose only 1,2 or 3!
                  """)
        
    if pharaoh_choice == '1':
        print("""
------------------------------------------------------------------------------
Pharaoh appreciate your worship for his power. He name you his biggest admirer
and order to burry you with himat his beautiful Piramid...
------------------------------------------------------------------------------
            """)
        
        time.sleep(2)
        
        print("""
------------------------------------------------------------------------------
Lucky for you Pharaoh Ramses the Great's reigh was pretty long. He was Pharaoh
for over 70 years and had 96 kids.

██╗   ██╗ ██████╗ ██╗   ██╗    ██╗    ██╗ ██████╗ ███╗   ██╗██╗
╚██╗ ██╔╝██╔═══██╗██║   ██║    ██║    ██║██╔═══██╗████╗  ██║██║
 ╚████╔╝ ██║   ██║██║   ██║    ██║ █╗ ██║██║   ██║██╔██╗ ██║██║
  ╚██╔╝  ██║   ██║██║   ██║    ██║███╗██║██║   ██║██║╚██╗██║╚═╝
   ██║   ╚██████╔╝╚██████╔╝    ╚███╔███╔╝╚██████╔╝██║ ╚████║██╗
   ╚═╝    ╚═════╝  ╚═════╝      ╚══╝╚══╝  ╚═════╝ ╚═╝  ╚═══╝╚═╝
   
               (well, by now...)
------------------------------------------------------------------------------
                    """)
        
        time.sleep(2)
        you_lost() #Back to restart menu
            
    elif pharaoh_choice == '2':
        print("""
------------------------------------------------------------------------------
You approach the Pharaoh and tell him how pleased you are to be a part of this
great event. You firmly shake his hand and wish him to rule Egypt for at least
the next 70 years.
Ramses accept your congratulations with a wide smile. 
Eygupt adopt shandshake as a gesture of respect and admiration!

██╗   ██╗ ██████╗ ██╗   ██╗    ██╗    ██╗ ██████╗ ███╗   ██╗██╗
╚██╗ ██╔╝██╔═══██╗██║   ██║    ██║    ██║██╔═══██╗████╗  ██║██║
 ╚████╔╝ ██║   ██║██║   ██║    ██║ █╗ ██║██║   ██║██╔██╗ ██║██║
  ╚██╔╝  ██║   ██║██║   ██║    ██║███╗██║██║   ██║██║╚██╗██║╚═╝
   ██║   ╚██████╔╝╚██████╔╝    ╚███╔███╔╝╚██████╔╝██║ ╚████║██╗
   ╚═╝    ╚═════╝  ╚═════╝      ╚══╝╚══╝  ╚═════╝ ╚═╝  ╚═══╝╚═╝
------------------------------------------------------------------------------
            """)
        
        time.sleep(2)
        you_lost() #Back to restart menu
        
    elif pharaoh_choice == '3':
        print("""
------------------------------------------------------------------------------
Yes, there will be a party after!
But sadly enought, according to acient Egypt traditions, party consider to be 
pretty boring without couple sacrifices. That's why they party like the last 
party in their lives....
------------------------------------------------------------------------------
            """)
            
        time.sleep(2)
            
        print("""
------------------------------------------------------------------------------
You was sacrificed as the biggest party animal, which was documented on one of
the egyptian manuscrips...
Too bad no one ever decrypt it.

██╗   ██╗ ██████╗ ██╗   ██╗    ██╗      ██████╗ ███████╗████████╗██╗
╚██╗ ██╔╝██╔═══██╗██║   ██║    ██║     ██╔═══██╗██╔════╝╚══██╔══╝██║
 ╚████╔╝ ██║   ██║██║   ██║    ██║     ██║   ██║███████╗   ██║   ██║
  ╚██╔╝  ██║   ██║██║   ██║    ██║     ██║   ██║╚════██║   ██║   ╚═╝
   ██║   ╚██████╔╝╚██████╔╝    ███████╗╚██████╔╝███████║   ██║   ██╗
   ╚═╝    ╚═════╝  ╚═════╝     ╚══════╝ ╚═════╝ ╚══════╝   ╚═╝   ╚═╝ 
------------------------------------------------------------------------------
            """)
        
        time.sleep(2)
        you_lost() #Back to restart menu
        
    else:
        print("Seems like something is wrong.")
        time.sleep(2)
        you_lost() #Back to restart menu
#-----------------------------------------------------------------------------


def you_lost():
    restart = input(f"""
Seems like the game is over for you, do you want to go back to the time-travel menu?
1. Yes
2. No
\t---{name}'s answer:
                      """)
    
    restart = restart.casefold()
    
    if restart == '1'or 'yes' in restart:
        start_the_game()
    elif restart == '2' or 'no' in restart:
        print("\nThank you for choosing our time lab. We hope to see you again!")
        input("<Press enter to exit the game.>")
        exit(0)
    else:
        print("\nSeems like something is wrong.")
        
introduction()
# Out:
#  █████╗ ██╗  ████████╗███████╗██████╗ ███╗   ██╗ █████╗ ██╗     ██╗████████╗██╗   ██╗
# ██╔══██╗██║  ╚══██╔══╝██╔════╝██╔══██╗████╗  ██║██╔══██╗██║     ██║╚══██╔══╝╚██╗ ██╔╝
# ███████║██║     ██║   █████╗  ██████╔╝██╔██╗ ██║███████║██║     ██║   ██║    ╚████╔╝
# ██╔══██║██║     ██║   ██╔══╝  ██╔══██╗██║╚██╗██║██╔══██║██║     ██║   ██║     ╚██╔╝
# ██║  ██║███████╗██║   ███████╗██║  ██║██║ ╚████║██║  ██║███████╗██║   ██║      ██║
# ╚═╝  ╚═╝╚══════╝╚═╝   ╚══════╝╚═╝  ╚═╝╚═╝  ╚═══╝╚═╝  ╚═╝╚══════╝╚═╝   ╚═╝      ╚═╝
#
#
# ------------------------------------------------------------------------------
# Hello and Welcome to our brand new, recently open, 73% safe time travel lab!
#
# Here we are offering you an unforgettable experience of jumping back and
# forward in time with unexpectable health issues. And we are happy to have you
# as our first timonaft!
# ------------------------------------------------------------------------------
#
# Can I ask you for your name?
#
# ...
